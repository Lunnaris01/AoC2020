# %%
import numpy as np
import pandas as pd
import re
data = np.array(pd.read_csv("../res/input_4.txt",header=None,skip_blank_lines = False,error_bad_lines=False).fillna("NEXTLINE"))
print(data)
# Out:
# [['ecl:#eef340 eyr:2023 hcl:#c0946f pid:244684338 iyr:2020 cid:57 byr:1969 hgt:152cm']
#  ['NEXTLINE']
#  ['pid:303807545 cid:213 ecl:gry hcl:#fffffd']
#  ...
#  ['eyr:2021']
#  ['hcl:#602927 iyr:2014']
#  ['pid:274974402 hgt:183cm']]

# %%
def isvalid_first(line):
    req = ['ecl','pid','eyr','hcl','byr','iyr','hgt']
    for r in req:
        if r not in line:
            return 0
    return 1

def isvalid_second(line):
    eyecols = ['amb','blu','brn','gry','grn','hzl','oth']
    fields = line.split(" ")
    for field in fields:
        key,val = field.split(":")
        if key == "byr":
            if(int(val)<1920 or int(val)>2002):
                return 0
        if key == "iyr":
            if(int(val)<2010 or int(val)>2020):
                return 0
        if key == "eyr":
            if(int(val)<2020 or int(val)>2030):
                return 0
        if key == "hgt":
            if not (re.search("cm|in",val)):
                return 0
            if(re.search("cm$",val)):
                hgt = int(val[0:-2])
                if (hgt<150 or hgt>193):
                    return 0
            if(re.search("in$",val)):
                hgt = int(val[0:-2])
                if(hgt<59 or hgt>76):
                    return 0
            
        if key == "hcl":
            if not(re.search("^#[1234567890abcdef]{6}",val)):
                return 0
        if key == "ecl":
            if val not in eyecols:
                return 0
        if key == "pid":
            if not(re.search("[0-9]{9}",val)):
                return 0            
            
    
    return 1

# %%
complete_line=''
counter = 0
for line in data:
    if(line[0] != "NEXTLINE"):
        complete_line = complete_line + " " + line[0]
    else:
        counter+= isvalid_first(complete_line)
        complete_line = ''
    #complete_line = complete_line + line[0]
counter+= isvalid_first(complete_line)

print(counter)
# Out:
# 206

# %%
complete_line=''
counter = 0
for line in data:
    if(line[0] != "NEXTLINE"):
        complete_line = complete_line + " " + line[0]
    else:
        complete_line = complete_line[1:]
        print(complete_line)
        if(isvalid_first(complete_line)):
            counter+= isvalid_second(complete_line)
        complete_line = ''
complete_line = complete_line[1:]
counter+= isvalid_second(complete_line)*isvalid_first(complete_line)
print(counter)
# Out:
# ecl:#eef340 eyr:2023 hcl:#c0946f pid:244684338 iyr:2020 cid:57 byr:1969 hgt:152cm
# pid:303807545 cid:213 ecl:gry hcl:#fffffd eyr:2038 byr:1951 hgt:171cm iyr:2011
# hcl:#c0946f byr:1933 eyr:2025 pid:517067213 hgt:173cm ecl:hzl iyr:2018
# pid:5253256652 byr:2009 hgt:152cm iyr:1989 eyr:1968 hcl:64cb63 ecl:hzl
# iyr:2013 pid:862607211 eyr:2020 hgt:174cm byr:1990 ecl:blu hcl:#888785
# ecl:grn byr:1955 pid:608098408 eyr:2027 iyr:2020 hcl:#b6652a cid:264 hgt:181cm
# byr:1998 ecl:hzl eyr:2021 hcl:#866857 hgt:189cm iyr:2030 pid:013735467
# pid:075417314 hcl:#b6652a byr:1957 iyr:2011 hgt:154cm eyr:2025 ecl:amb
# iyr:1993 hgt:74cm eyr:1960 byr:2029 hcl:293244 ecl:#3cb5e5 pid:4861232363
# hgt:153cm hcl:#6b5442 pid:065240897 byr:1932 cid:196 ecl:blu eyr:2028 iyr:2019
# eyr:2024 ecl:amb hcl:#866857 byr:1922 pid:496904942 hgt:164cm iyr:2020
# pid:847705161 byr:1951 cid:124 iyr:1991 eyr:2028 ecl:dne hcl:6b2d28 hgt:172cm
# byr:2007 iyr:2029 ecl:hzl eyr:2026 hgt:168in hcl:z pid:63151612
# ...

# %%
print(isvalid_second(test))
# Out:
# 0
